# %%
import pandas as pd

constellation = pd.read_csv('constellation_catalog.csv')

display(constellation)
# Out:
#          source_image       constellation_id  num_stars   centroid_x  \
# 0   resized_image.jpg  resized_image_const_0         15   121.066667
# 1           space.jpg          space_const_3        289  2232.145329
# 2           space.jpg         space_const_28         91  3804.000000
# 3           space.jpg         space_const_22         84   583.559524
# 4           space.jpg         space_const_30         29  1305.689655
# ..                ...                    ...        ...          ...
# 63         image0.jpg         image0_const_0         33   391.272727
# 64         image0.jpg         image0_const_2         33   885.757576
# 65         image0.jpg         image0_const_4         13   478.307692
# 66         image0.jpg         image0_const_3          9   243.555556
# 67         image0.jpg         image0_const_1          5   767.200000
#
#      centroid_y  avg_brightness  \
# 0    138.666667      161.201815
# 1   2817.923875      138.129897
# 2   1215.538462      138.453109
# ...
